# %%
from astropy.table import Table
from glob import glob
import os
from pathlib import Path
import matplotlib.pylab as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import make_axes_locatable

import numpy as np
import pandas as pd
import sys
sys.path.append('../modules/')
from ClustNet import Cluster
from ClustNet import dataset

import random

# %%
Cluster.plot()
# Out:
# ../modules/ClustNet/Cluster.py:243: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   cmap = cmap.set_bad(color='#DADADA')
# ../modules/ClustNet/Cluster.py:244: RuntimeWarning: divide by zero encountered in log10
#   ax.imshow(np.log10(image),interpolation='none',cmap=cmap)
# Dataset preview saved to: ./dataset_10x10_view.png

# %% [raw]
# x_train, y_train = Cluster.load_dataset(k='all')

# %% [raw]
# x = Cluster.Cluster()
# x.plot()
# x.add_border()
# x.plot()
# x.shift()
# x.plot()

# %%
clusglob = glob('../../data/eROSITA_no_background/*')
clusfpath = random.choice(clusglob)
clusfpath = '../../data/eROSITA_no_background/871021.fits'

# %%
x = Cluster.Cluster(fpath=clusfpath)
x.image
x.to_pandas()
x.plot()
x.add_border()
x.plot()
x.shift(64)
x.add_noise()
x.plot()

# %%
x.add_border()
x.plot()
x.shift()
x.plot()
