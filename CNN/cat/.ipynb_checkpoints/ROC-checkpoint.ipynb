# %%
# plotting
import matplotlib.pylab as plt
import matplotlib as mpl

# statistics
import numpy as np
import pandas as pd

# tensorflow
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# scikit
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score

# %%
modelpath = '../../models/category/Uyx2x'
model = keras.models.load_model(modelpath)

# %%
tr_paths = pd.read_csv(modelpath + '/tr_paths.txt',names=['path'])
val_paths = pd.read_csv(modelpath + '/val_paths.txt',names=['path'])

tr_paths['clus_bool'] = tr_paths['path']=='noise'
tr_paths['clus_bool'] = tr_paths['clus_bool'].astype(int)

val_paths['clus_bool'] = val_paths['path']=='noise'
val_paths['clus_bool'] = val_paths['clus_bool'].astype(int)
# Out:
#                                                   path  clus_bool
# 0                                                noise          1
# 1    /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eR...          0
# 2    /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eR...          0
# 3    /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eR...          0
# 4                                                noise          1
# ..                                                 ...        ...
# 745                                              noise          1
# 746  /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eR...          0
# 747                                              noise          1
# 748  /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eR...          0
# 749  /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eR...          0
#
# [750 rows x 2 columns]

# %%
for x_path in tr_paths['path']:
    if x_path == 'noise':
# Out:
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901821.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902153.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912426.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901663.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871371.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891697.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921333.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891784.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/870995.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881374.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921321.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871959.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921963.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911503.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921816.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921673.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912723.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901635.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901568.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921742.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871002.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921456.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911508.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921713.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912313.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912069.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871503.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/913733.fits
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912877.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871490.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881362.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901930.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/870983.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881533.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911643.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881519.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871223.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921444.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901585.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911779.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922119.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911827.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891965.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921656.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921525.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871910.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891492.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921395.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911729.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881443.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891546.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871179.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/892917.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921366.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901786.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881730.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/893252.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912607.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/923035.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901629.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922715.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901697.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881302.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902150.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891492.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901704.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921381.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921935.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911767.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/882158.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891728.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921950.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911701.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921536.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881309.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/913155.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891599.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871038.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881341.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881469.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891635.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921743.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871025.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902899.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871493.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911610.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911900.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912500.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891587.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871226.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881446.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891583.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911724.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911988.fits
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901741.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901860.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881346.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891518.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881500.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921325.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881303.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911683.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921468.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921363.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/892164.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902071.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881774.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921619.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922165.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901594.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871328.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921684.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871414.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881306.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871039.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/903223.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891933.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921480.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921389.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881521.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881308.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901690.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912141.fits
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881622.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922184.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901600.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881332.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921331.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911964.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891521.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902981.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911629.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/882460.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881409.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881559.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921682.fits
# noise
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921607.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921502.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911817.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911566.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911714.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871375.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871074.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/882141.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891552.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871487.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881986.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891628.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/882141.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921342.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902360.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871371.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871234.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901846.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891718.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911505.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912376.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911578.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891536.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921708.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911825.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881402.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922892.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871234.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871072.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881371.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911958.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922050.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921323.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/892432.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901836.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881634.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911710.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881490.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911889.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921444.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911625.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921350.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912016.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881345.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901667.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891479.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891599.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/870975.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891732.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921763.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901746.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881500.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901740.fits
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911572.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912019.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881357.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921319.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901882.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/882469.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902405.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871044.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921912.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881536.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911562.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911864.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901636.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902088.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921691.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891498.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891709.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921472.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/
fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911571.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922329.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911859.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912248.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901614.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902276.fits
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881884.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891708.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921340.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881551.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911906.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901606.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922510.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911521.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881396.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921321.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911827.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871910.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881766.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881609.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881733.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921835.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901586.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901848.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871432.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871152.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891732.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911834.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922334.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911535.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901650.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881536.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871533.fits
# noise
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881333.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921501.fits
# ...
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881935.fits
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912528.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/882014.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911549.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922000.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891582.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871210.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911678.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881410.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901594.fits
# noise
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891503.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891509.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921808.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871608.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912598.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901718.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921388.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921485.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911862.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912981.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871175.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871195.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871618.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912174.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881536.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901756.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901681.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871037.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911899.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911597.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/872012.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922259.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891768.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901636.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891982.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911545.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881492.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871159.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921517.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891577.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871982.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871080.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881826.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901648.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921510.fits
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/872448.fits
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921624.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921490.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921922.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/923035.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922654.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871172.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921443.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/882183.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911714.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901751.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871102.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922096.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/913733.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911774.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922035.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891549.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901656.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902405.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871426.fits
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902180.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/870981.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871025.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912684.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/892713.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891754.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881440.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901580.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871195.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911612.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912528.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901661.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911659.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881706.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891591.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922262.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922195.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902950.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881343.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/923270.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/892157.fits
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881300.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921423.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921985.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922735.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912456.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881410.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891590.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911859.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871894.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911654.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881371.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881974.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921521.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921633.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921787.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871708.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921346.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/913031.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871006.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902086.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871049.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881332.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911687.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901846.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911758.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871110.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911640.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891568.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902276.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/882448.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901792.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921690.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881425.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881314.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871051.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871052.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891880.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922455.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922212.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871186.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901848.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901709.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871056.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901567.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871328.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921747.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891739.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/870989.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881370.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871032.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871426.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922414.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871076.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871040.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871996.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891640.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901755.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901583.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891541.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911618.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901852.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881383.fits
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901735.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912548.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871736.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921933.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/922598.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891616.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871078.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871917.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/912121.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921658.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881753.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921932.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871105.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/902672.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911536.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891585.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911682.fits
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901799.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901580.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891582.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891664.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901750.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921684.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871114.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901788.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871346.fits
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921894.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921690.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921912.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/921620.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891749.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871792.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911522.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881561.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/911553.fits
# noise
# noise
# noise
# noise
# noise
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/871533.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881404.fits
# noise
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/881418.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901599.fits
# noise
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/901724.fits
# /home-1/bgalgan1@jhu.edu/repos/ClusNet/data/eROSITA_no_background/891903.fits
# noise

# %%
y_train_model = model.predict(x_train,verbose=1)    
validation_y_model = model.predict(validation_x,verbose=1)

# %%
plt.figure(figsize=[5,5])
fpr = dict()
tpr = dict()
roc_auc = dict()

pred = df[color + '_dwf_gnt_ratio']
test = df['lumcls']

for i in range(2):
    fpr[i], tpr[i], _ = roc_curve(test, pred)
    roc_auc[i] = auc(fpr[i], tpr[i])

roc = roc_auc_score(test, pred)
plt.plot(fpr[1], tpr[1],label='{:} (AUC={:.2f})'.format(spec,roc),lw=1)
    
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.plot([0, 1], [0, 1], 'k',lw=1,zorder=0)
plt.legend()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.tight_layout()
#plt.savefig('roc_binary_classifer.png',dpi=300,bbox_inches='tight')
plt.show()
