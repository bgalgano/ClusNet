# %%
import numpy as np
import random
import matplotlib.pylab as plt
from scipy import signal
from mpl_toolkits.axes_grid1 import make_axes_locatable

from tensorflow.keras.optimizers import Adam
import matplotlib as mpl

label_size = 14

mpl.rcParams['legend.fontsize'] = label_size
mpl.rcParams['axes.labelsize'] = label_size 

mpl.rcParams['xtick.labelsize'] = label_size
mpl.rcParams['ytick.labelsize'] = label_size

mpl.rcParams['axes.labelpad'] = 10

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

np.set_printoptions(precision=3, suppress=True)
from sklearn.model_selection import train_test_split

# %%
class Profile:
    def __init__(self,std,size):
        self.mid_pixel = size/2 # 128/2
        self.x, self.y = self.mid_pixel, self.mid_pixel
        self.size = size
        self.std = std
        self.noise = False
        self.lam = 0.1133929878
        gkern1d = signal.gaussian(self.size, std=std).reshape(self.size, 1)
        self.image = np.outer(gkern1d, gkern1d)


    def __repr__(self):
        """
        print cluster metadata
        """
        return str(self.image)
    
    def to_pandas(self):
        """
        convert metadata (as recarray) to pandas DataFrame
        """
        self.meta = pd.DataFrame(self.meta)
        return
    
    def add_noise(self):
        """
        add Poisson noise to cluster image matrix
        """
        self.noise = np.random.poisson(lam=self.lam, size=self.image.shape)
        self.image += self.noise
        return
        
    def shift(self):
        """
        shift cluster randomly within bounds of image
        """
        """
        shift cluster randomly within bounds of image
        """
        r = self.std
        mid = self.mid_pixel #center pixel index of 384x384 image
        delta = self.size - self.mid_pixel - r
        
        x = np.random.randint(low=-1*delta,high=delta,size=1)[0]
        y = np.random.randint(low=-1*delta,high=delta,size=1)[0]

        self.x += x
        self.y += y
        image_shift = np.roll(self.image,shift=x,axis=0)
        self.image = np.roll(image_shift,shift=y,axis=1)
        
        return 
    
    def plot(self,spath='../figs/profile/'):
        """
        plot image
        """
        fig = plt.figure()
        ax = fig.add_subplot(111)
        im = ax.imshow(self.image,interpolation='none',cmap='viridis')
        
        ticks = np.arange(0,self.size,50)
        plt.xticks(ticks),plt.yticks(ticks)
        #plt.title(r'$loc={}, scale={}$'.format(self.loc,self.scale))

        ax = plt.gca()
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.12)

        plt.colorbar(im, cax=cax)
        plt.show()
        plt.close()
        return None

# %%
size = 128
profile_set = []
for profile in range(1000):
    std = np.random.randint(low=1,high=10,size=1)
    x = Profile(std=std,size=size)
    x.add_noise()
    x.shift()
    profile_set.append(x)

# %%
# plot a sample of 100 circles from our dataset
fig, axes = plt.subplots(nrows=10,ncols=10,figsize=(9,9))
for i, ax in enumerate(axes.flat):
    prof = profile_set[i]
    ax.imshow(prof.image,interpolation='none',cmap='binary')
    ax.set_yticks([])
    ax.set_xticks([])
space= 0.1
plt.subplots_adjust(wspace=space,hspace=space)
plt.tight_layout()
#plt.savefig('10x10_rand_circ.png',dpi=300)
plt.show()

plt.close()

# %%
input_shape = (size,size,1) # width, height, channel number
pool_size = (2,2)
kernel_size = (3,3)
activation = 'relu'
strides = 2

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(size,size,1)),
        
        # 1. 3×3 convolution with 16 filters
        layers.Conv2D(filters=16, kernel_size=kernel_size, activation=activation),

        # 2. 2×2, stride-2 max pooling
        layers.MaxPooling2D(pool_size=pool_size, strides=strides),

        # 3. 3×3 convolution with 32 filters
        layers.Conv2D(filters=32, kernel_size=kernel_size, activation=activation),

        # 4. 2×2, stride-2 max pooling
        layers.MaxPooling2D(pool_size=pool_size, strides=strides),

        # 5. 3×3 convolution with 64 filters
        layers.Conv2D(filters=64, kernel_size=kernel_size, activation=activation),

        # 6. 2×2, stride-2 max pooling
        layers.MaxPooling2D(pool_size=pool_size, strides=strides),

        # 7. global average pooling
        layers.GlobalAveragePooling2D(),

        # 8. 10% dropout
        layers.Dropout(0.1),

        # 9. 200 neurons, fully connected
        layers.Dense(units=200),

        # 10. 10% dropout
        layers.Dropout(0.1),

        # 11. 100 neurons, fully connected
        layers.Dense(units=100),

        # 12. 20 neurons, fully connected
        layers.Dense(units=20),

        # 13. output neuron
        layers.Dense(units=1)

    ]
)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 126, 126, 16)      160
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 63, 63, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 61, 61, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 200)               13000
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_10 (Dense)             (None, 20)                2020
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 58,437
# Trainable params: 58,437
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the keras model on the dataset
data = np.array([prof.image for prof in profile_set])
labels = np.array([prof.std for prof in profile_set])

idx = np.arange(0,1000,1)
test_idx = random.sample(list(idx),k=100)
train_idx = np.delete(idx, test_idx)

x_train, y_train = data[train_idx], labels[train_idx]
x_test, y_test = data[test_idx], labels[test_idx]

x_train = x_train.reshape(-1, size, size, 1)
x_test = x_test.reshape(-1, size, size, 1)

# %%
#labels = tf.expand_dims(labels, axis=-1)
opt = Adam(lr=0.0005)
model.compile(optimizer=opt,loss="mse", metrics=["accuracy"])
model.fit(x=x_train,y=y_train, epochs=250, batch_size=size, validation_split=0.1,verbose=1)
# Out:
# Epoch 1/250
# 7/7 [==============================] - 3s 317ms/step - loss: 25.1668 - accuracy: 0.0416 - val_loss: 13.2756 - val_accuracy: 0.1111
# Epoch 2/250
# 7/7 [==============================] - 2s 283ms/step - loss: 8.7531 - accuracy: 0.0920 - val_loss: 9.6710 - val_accuracy: 0.1111
# Epoch 3/250
# 7/7 [==============================] - 2s 283ms/step - loss: 8.0602 - accuracy: 0.0845 - val_loss: 8.6861 - val_accuracy: 0.1111
# Epoch 4/250
# 7/7 [==============================] - 2s 282ms/step - loss: 7.6498 - accuracy: 0.0948 - val_loss: 8.1257 - val_accuracy: 0.1111
# Epoch 5/250
# 7/7 [==============================] - 2s 281ms/step - loss: 6.7405 - accuracy: 0.0928 - val_loss: 7.4990 - val_accuracy: 0.1111
# Epoch 6/250
# 7/7 [==============================] - 2s 291ms/step - loss: 6.5763 - accuracy: 0.0919 - val_loss: 7.5818 - val_accuracy: 0.1111
# Epoch 7/250
# 7/7 [==============================] - 2s 282ms/step - loss: 6.8012 - accuracy: 0.1023 - val_loss: 7.4346 - val_accuracy: 0.1111
# Epoch 8/250
# 7/7 [==============================] - 2s 286ms/step - loss: 6.5559 - accuracy: 0.0936 - val_loss: 7.2527 - val_accuracy: 0.1111
# Epoch 9/250
# 7/7 [==============================] - 2s 288ms/step - loss: 0.7314 - accuracy: 0.0772 - val_loss: 0.6423 - val_accuracy: 0.1111
# Epoch 229/250
# 7/7 [==============================] - 2s 283ms/step - loss: 0.7714 - accuracy: 0.1036 - val_loss: 0.6000 - val_accuracy: 0.1111
# Epoch 230/250
# 7/7 [==============================] - 2s 281ms/step - loss: 0.6898 - accuracy: 0.0895 - val_loss: 0.6151 - val_accuracy: 0.1111
# Epoch 231/250
# 7/7 [==============================] - 2s 282ms/step - loss: 0.7398 - accuracy: 0.0904 - val_loss: 0.6103 - val_accuracy: 0.1111
# Epoch 232/250
# 7/7 [==============================] - 2s 281ms/step - loss: 0.6845 - accuracy: 0.0948 - val_loss: 0.6888 - val_accuracy: 0.1111
# Epoch 233/250
# 7/7 [==============================] - 2s 288ms/step - loss: 0.6802 - accuracy: 0.0868 - val_loss: 0.6433 - val_accuracy: 0.1111
# Epoch 234/250
# 7/7 [==============================] - 2s 284ms/step - loss: 0.8149 - accuracy: 0.0860 - val_loss: 0.6317 - val_accuracy: 0.1111
# Epoch 235/250
# 7/7 [==============================] - 2s 284ms/step - loss: 0.7607 - accuracy: 0.0986 - val_loss: 0.5960 - val_accuracy: 0.1111
# Epoch 236/250
# 7/7 [==============================] - 2s 281ms/step - loss: 0.7312 - accuracy: 0.1004 - val_loss: 0.6363 - val_accuracy: 0.1111
# Epoch 237/250
# 7/7 [==============================] - 2s 283ms/step - loss: 0.6978 - accuracy: 0.1005 - val_loss: 0.6986 - val_accuracy: 0.1111
# Epoch 238/250
# 7/7 [==============================] - 2s 282ms/step - loss: 0.7396 - accuracy: 0.0899 - val_loss: 0.6149 - val_accuracy: 0.1111
# Epoch 239/250
# 7/7 [==============================] - 2s 286ms/step - loss: 0.7026 - accuracy: 0.0993 - val_loss: 0.5962 - val_accuracy: 0.1111
# Epoch 240/250
# 7/7 [==============================] - 2s 292ms/step - loss: 0.6901 - accuracy: 0.1033 - val_loss: 0.7041 - val_accuracy: 0.1111
# Epoch 241/250
# 7/7 [==============================] - 2s 292ms/step - loss: 0.7115 - accuracy: 0.1031 - val_loss: 0.5897 - val_accuracy: 0.1111
# Epoch 242/250

# %%
train_pred = model.predict(x_train,verbose=1)
test_pred = model.predict(x_test,verbose=1)

# %%
fig, ax = plt.subplots(figsize=(5,5))

ax.scatter(y_train,train_pred,s=5,marker=".",label='Training data')
ax.scatter(y_test,test_pred,s=5,marker=".",label='Test data')

lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.5, zorder=200)
ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)

ax.set_xlabel('Original Radius')
ax.set_ylabel('CNN Radius')
ticks = np.arange(10,51,5)
ax.set_xticks(ticks),ax.set_yticks(ticks)
plt.title('Shifted',fontsize=15)
plt.legend()
plt.tight_layout()
#plt.savefig('1to1_plot_radius_approx-shift.png',dpi=250,bbox_inches='tight')
plt.show()
plt.close()
